# %%
import urllib.request
import pandas as pd

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2018&$limit=10000"
checkout_file = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7f3983157510>)

# %%
checkouts_df = pd.read_csv(checkout_file)

# %%
checkouts_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2018              1
# 1       Digital       Hoopla   TELEVISION          2018              1
# 2      Physical      Horizon    SOUNDDISC          2018              1
# 3       Digital    OverDrive        EBOOK          2018              1
# 4       Digital    OverDrive        EBOOK          2018              1
# ...         ...          ...          ...           ...            ...
# 9995    Digital    OverDrive        EBOOK          2018              1
# 9996    Digital    OverDrive        EBOOK          2018              1
# 9997    Digital      Freegal         SONG          2018              1
# 9998   Physical      Horizon         BOOK          2018              1
# 9999   Physical      Horizon    SOUNDDISC          2018              1
#
#       checkouts                                              title  isbn  \
# ...

# %%
## Wieviele Medien wurden digital ausgeliehen?

# %%
checkouts_df["usageclass"]
# Out:
# 0        Digital
# 1        Digital
# 2       Physical
# 3        Digital
# 4        Digital
#           ...
# 9995     Digital
# 9996     Digital
# 9997     Digital
# 9998    Physical
# 9999    Physical
# Name: usageclass, Length: 10000, dtype: object

# %%
checkouts_df[checkouts_df["usageclass"] == "Digital"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2018              1
# 1       Digital       Hoopla   TELEVISION          2018              1
# 3       Digital    OverDrive        EBOOK          2018              1
# 4       Digital    OverDrive        EBOOK          2018              1
# 5       Digital    OverDrive        EBOOK          2018              1
# ...         ...          ...          ...           ...            ...
# 9991    Digital      Freegal         SONG          2018              1
# 9992    Digital    OverDrive        EBOOK          2018              1
# 9995    Digital    OverDrive        EBOOK          2018              1
# 9996    Digital    OverDrive        EBOOK          2018              1
# 9997    Digital      Freegal         SONG          2018              1
#
#       checkouts                                              title  isbn  \
# ...

# %%
digital_lendings = checkouts_df[checkouts_df["usageclass"] == "Digital"]

# %%
digital_lendings.shape
# Out:
# (4021, 12)

# %%
checkouts_df["usageclass"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='usageclass'>

# %%
## Welche digitalen Medien wurden ausgeliehen

# %%
digital_lendings["materialtype"]
# Out:
# 0            EBOOK
# 1       TELEVISION
# 3            EBOOK
# 4            EBOOK
# 5            EBOOK
#            ...
# 9991          SONG
# 9992         EBOOK
# 9995         EBOOK
# 9996         EBOOK
# 9997          SONG
# Name: materialtype, Length: 4021, dtype: object

# %%
digital_lendings["materialtype"].value_counts()
# Out:
# materialtype
# EBOOK         2084
# AUDIOBOOK      857
# SONG           707
# MUSIC          117
# MOVIE           94
# TELEVISION      85
# COMIC           62
# MAGAZINE        10
# VIDEO            5
# Name: count, dtype: int64

# %%
lending_types = digital_lendings["materialtype"].value_counts()

# %%
lending_types.plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
## Welches Medium wurde am häufigsten ausgeliehen

# %%
most_wanted = checkouts_df[["checkouts", "title"]]

# %%
most_wanted
# Out:
#       checkouts                                              title
# 0            22                                 Enemy of the State
# 1             1     Newspaper Mom / Cucumber in Rio / Donut Raffle
# 2             1                              Mono / the Mavericks.
# 3             2                                      Anna Karenina
# 4             1                        Dragon: Vlad Series, Book 8
# ...         ...                                                ...
# 9995          1             Immortal: Fallen Angels Series, Book 6
# 9996          1                               The Price of Silence
# 9997          1                                    Desert Hideaway
# 9998          3             Waistcoats & weaponry / Gail Carriger.
# 9999          1  Red moon rising : [Sputnik and the hidden riva...
#
# [10000 rows x 2 columns]

# %%
most_wanted.sort_values(by="checkouts")
# Out:
#       checkouts                                              title
# 9999          1  Red moon rising : [Sputnik and the hidden riva...
# 3741          1  Road to Avonlea. The complete fifth volume / S...
# 3740          1                           Street Spirit (Fade Out)
# 3738          1                                 The natural house.
# 7346          1  Lucky Bastard: My Life, My Dad, and the Things...
# ...         ...                                                ...
# 6084        114           George & Lizzie : a novel / Nancy Pearl.
# 7785        176  Hidden figures / 20th Century Fox ; Fox 2000 P...
# 9255        354                                      The Economist
# 9700        495  Her body and other parties : stories / Carmen ...
# 6638        540  In the midst of winter : a novel / Isabel Alle...
#
# [10000 rows x 2 columns]

# %%
most_wanted.sort_values(by="checkouts", ascending=False)
# Out:
#       checkouts                                              title
# 6638        540  In the midst of winter : a novel / Isabel Alle...
# 9700        495  Her body and other parties : stories / Carmen ...
# 9255        354                                      The Economist
# 7785        176  Hidden figures / 20th Century Fox ; Fox 2000 P...
# 6084        114           George & Lizzie : a novel / Nancy Pearl.
# ...         ...                                                ...
# 1787          1        The Complete Guide to Garden Walls & Fences
# 5605          1                          Stand by Faith: Rehearsal
# 5604          1                                Joanne / Lady Gaga.
# 1788          1                     Leaving Berlin / Joseph Kanon.
# 9999          1  Red moon rising : [Sputnik and the hidden riva...
#
# [10000 rows x 2 columns]

# %%
##
