# %%
# Installieren
# %pip install python-terrier
# Out:
# Requirement already satisfied: python-terrier in ./anaconda3/lib/python3.11/site-packages (0.10.0)
# Requirement already satisfied: numpy in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (1.24.3)
# Requirement already satisfied: pandas in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (2.0.3)
# Requirement already satisfied: wget in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (3.2)
# Requirement already satisfied: tqdm in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (4.65.0)
# Requirement already satisfied: pyjnius>=1.4.2 in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (1.6.1)
# Requirement already satisfied: matchpy in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (0.5.5)
# Requirement already satisfied: scikit-learn in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (1.3.0)
# Requirement already satisfied: deprecated in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (1.2.14)
# Requirement already satisfied: chest in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (0.2.3)
# Requirement already satisfied: scipy in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (1.11.1)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (2.31.0)
# Requirement already satisfied: joblib in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (1.2.0)
# Requirement already satisfied: nptyping==1.4.4 in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (1.4.4)
# Requirement already satisfied: more-itertools in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (8.12.0)
# Requirement already satisfied: ir-datasets>=0.3.2 in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (0.5.5)
# Requirement already satisfied: jinja2 in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (3.1.2)
# Requirement already satisfied: statsmodels in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (0.14.0)
# Requirement already satisfied: ir-measures>=0.3.1 in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (0.3.3)
# Requirement already satisfied: dill in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (0.3.6)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in ./anaconda3/lib/python3.11/site-packages (from python-terrier) (0.5.6)
# Requirement already satisfied: typish>=1.7.0 in ./anaconda3/lib/python3.11/site-packages (from nptyping==1.4.4->python-terrier) (1.9.3)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in ./anaconda3/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (4.12.2)
# Requirement already satisfied: inscriptis>=2.2.0 in ./anaconda3/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (2.4.0.1)
# Requirement already satisfied: lxml>=4.5.2 in ./anaconda3/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (4.9.3)
# Requirement already satisfied: pyyaml>=5.3.1 in ./anaconda3/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (6.0)
# Requirement already satisfied: trec-car-tools>=2.5.4 in ./anaconda3/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in ./anaconda3/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (4.3.2)
# Requirement already satisfied: warc3-wet>=0.2.3 in ./anaconda3/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.3)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in ./anaconda3/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in ./anaconda3/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (0.1.6)
# Requirement already satisfied: ijson>=3.1.3 in ./anaconda3/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (3.2.3)
# Requirement already satisfied: pyautocorpus>=0.1.1 in ./anaconda3/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (0.1.12)
# Requirement already satisfied: unlzw3>=0.2.1 in ./anaconda3/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.2)
# Requirement already satisfied: cwl-eval>=1.0.10 in ./anaconda3/lib/python3.11/site-packages (from ir-measures>=0.3.1->python-terrier) (1.0.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.11/site-packages (from requests->python-terrier) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.11/site-packages (from requests->python-terrier) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.11/site-packages (from requests->python-terrier) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.11/site-packages (from requests->python-terrier) (2023.7.22)
# Requirement already satisfied: heapdict in ./anaconda3/lib/python3.11/site-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in ./anaconda3/lib/python3.11/site-packages (from deprecated->python-terrier) (1.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.11/site-packages (from jinja2->python-terrier) (2.1.1)
# Requirement already satisfied: multiset<3.0,>=2.0 in ./anaconda3/lib/python3.11/site-packages (from matchpy->python-terrier) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.local/lib/python3.11/site-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.11/site-packages (from pandas->python-terrier) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./anaconda3/lib/python3.11/site-packages (from pandas->python-terrier) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn->python-terrier) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in ./anaconda3/lib/python3.11/site-packages (from statsmodels->python-terrier) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in ./.local/lib/python3.11/site-packages (from statsmodels->python-terrier) (23.2)
# Requirement already satisfied: soupsieve>1.2 in ./anaconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier) (2.4)
# Requirement already satisfied: six in ./.local/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels->python-terrier) (1.16.0)
# Requirement already satisfied: cbor>=1.0.0 in ./anaconda3/lib/python3.11/site-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier) (1.0.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in ./anaconda3/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: click in ./anaconda3/lib/python3.11/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in ./anaconda3/lib/python3.11/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in ./anaconda3/lib/python3.11/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in ./anaconda3/lib/python3.11/site-packages (from nltk) (4.65.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyterrier as pt
import requests
import pandas as pd
import pickle
import nltk
import numpy as np

# %%
# json in dataframe umwandeln

# %%
import json

# %%
data = json.loads(open("/home/anni/Schreibtisch/2023-2024-Data_Librarian_Ann-Kathrin_Christann/Modul_2/Modul_2-1/jsonoutput.json").read())

# %%
df = pd.DataFrame(data)

# %%
# pyterrier initialisieren

if not pt.started():
    pt.init()
# Out:
# terrier-assemblies 5.8 jar-with-dependencies not found, downloading to /home/anni/.pyterrier...
#   5% [..                                                ]   5431296 / 104292653
#   9% [....                                              ]  10149888 / 104292653
#  13% [......                                            ]  14565376 / 104292653
#  19% [.........                                         ]  19873792 / 104292653
#  23% [...........                                       ]  24764416 / 104292653
#  29% [..............                                    ]  30367744 / 104292653
#  34% [.................                                 ]  35667968 / 104292653
#  39% [...................                               ]  40984576 / 104292653
#  43% [.....................                             ]  45883392 / 104292653
#  48% [........................                          ]  50061312 / 104292653
#  50% [.........................                         ]  53125120 / 104292653
#  53% [..........................                        ]  55451648 / 104292653
#  56% [............................                      ]  58564608 / 104292653
#  59% [.............................                     ]  62103552 / 104292653
#  62% [...............................                   ]  65609728 / 104292653
#  65% [................................                  ]  68771840 / 104292653
#  69% [..................................                ]  72507392 / 104292653
#  73% [....................................              ]  76472320 / 104292653
#  76% [......................................            ]  79732736 / 104292653
#  79% [.......................................           ]  83255296 / 104292653
#  83% [.........................................         ]  86695936 / 104292653
#  87% [...........................................       ]  91316224 / 104292653
#  91% [.............................................     ]  95821824 / 104292653
#  96% [................................................  ] 100311040 / 104292653
# 100% [..................................................] 104292653 / 104292653Done
# terrier-python-helper 0.0.8 jar not found, downloading to /home/anni/.pyterrier...
# 100% [..........................................................] 37524 / 37524Done
# PyTerrier 0.10.0 has loaded Terrier 5.8 (built by craigm on 2023-11-01 18:05) and terrier-helper 0.0.8
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.

# %%
# docno und text Feld

# %%
df
# Out:
#                                                   title  \
# 0                   The oracles of Apollo in Asia Minor
# 1                                                Apollo
# 2                     The soviet space race with apollo
# 3     Biggest for-profit education company makes bid...
# 4     The Westminster Briefing: Presentation 5: Acce...
# ...                                                 ...
# 2899  Using Merkle Tree to Mitigate Cooperative Blac...
# 2900  Microscopic Origin of the Bekenstein-Hawking E...
# 2901     Instability of hyper-compact Kerr-like objects
# 2902  Supersymmetric black rings and three-charge su...
# 2903  Entropy of three-dimensional asymptotically fl...
#
#                                                 authors         type  \
# 0                                    [Herbert W. Parke]  Publication
# 1                                          [Fritz Graf]  Publication
# 2                                     [Asif A. Siddiqi]  Publication
# 3                                   [Goldie Blumenstyk]  Publication
# 4                                       [David Wasdell]  Publication
# ...                                                 ...          ...
# 2899                          [Mohammad Talib Shree Om]  Publication
# 2900                           [A. Strominger, C. Vafa]  Publication
# 2901  [Vitor Cardoso, Paolo Pani, Mariano Cadoni, Ma...  Publication
# 2902  [Henriette Elvang, Roberto Emparan, David Mate...  Publication
# 2903                                    [Glenn Barnich]  Publication
#
#                                                  source  searchterm  \
# 0     https://www.bibsonomy.org/bibtex/22a964918445b...      apollo
# 1     https://www.bibsonomy.org/bibtex/2b58cdf90ec31...      apollo
# 2     https://www.bibsonomy.org/bibtex/20c909b757857...      apollo
# 3     https://www.bibsonomy.org/bibtex/250b4e765ba47...      apollo
# 4     https://www.bibsonomy.org/bibtex/21ea727184e9a...      apollo
# ...                                                 ...         ...
# 2899  https://www.bibsonomy.org/bibtex/2008452621683...  black_hole
# 2900  https://www.bibsonomy.org/bibtex/2bf142cb41666...  black_hole
# 2901  https://www.bibsonomy.org/bibtex/23eafd6303b9d...  black_hole
# 2902  https://www.bibsonomy.org/bibtex/220a9c864de99...  black_hole
# 2903  https://www.bibsonomy.org/bibtex/25669ce9d778f...  black_hole
#
#       publication_year
# 0                 1985
# 1                 2009
# 2                 2003
# 3                 2004
# 4                 2007
# ...                ...
# 2899              2011
# 2900              1996
# 2901              2008
# 2902              2005
# 2903              2012
#
# [2904 rows x 6 columns]

# %%
df['docno'] = df['source']
df['text'] = df['title']

# %%
df
# Out:
#                                                   title  \
# 0                   The oracles of Apollo in Asia Minor
# 1                                                Apollo
# 2                     The soviet space race with apollo
# 3     Biggest for-profit education company makes bid...
# 4     The Westminster Briefing: Presentation 5: Acce...
# ...                                                 ...
# 2899  Using Merkle Tree to Mitigate Cooperative Blac...
# 2900  Microscopic Origin of the Bekenstein-Hawking E...
# 2901     Instability of hyper-compact Kerr-like objects
# 2902  Supersymmetric black rings and three-charge su...
# 2903  Entropy of three-dimensional asymptotically fl...
#
#                                                 authors         type  \
# 0                                    [Herbert W. Parke]  Publication
# 1                                          [Fritz Graf]  Publication
# 2                                     [Asif A. Siddiqi]  Publication
# 3                                   [Goldie Blumenstyk]  Publication
# 4                                       [David Wasdell]  Publication
# ...                                                 ...          ...
# 2899                          [Mohammad Talib Shree Om]  Publication
# 2900                           [A. Strominger, C. Vafa]  Publication
# 2901  [Vitor Cardoso, Paolo Pani, Mariano Cadoni, Ma...  Publication
# 2902  [Henriette Elvang, Roberto Emparan, David Mate...  Publication
# 2903                                    [Glenn Barnich]  Publication
#
#                                                  source  searchterm  \
# 0     https://www.bibsonomy.org/bibtex/22a964918445b...      apollo
# 1     https://www.bibsonomy.org/bibtex/2b58cdf90ec31...      apollo
# 2     https://www.bibsonomy.org/bibtex/20c909b757857...      apollo
# 3     https://www.bibsonomy.org/bibtex/250b4e765ba47...      apollo
# 4     https://www.bibsonomy.org/bibtex/21ea727184e9a...      apollo
# ...                                                 ...         ...
# 2899  https://www.bibsonomy.org/bibtex/2008452621683...  black_hole
# 2900  https://www.bibsonomy.org/bibtex/2bf142cb41666...  black_hole
# 2901  https://www.bibsonomy.org/bibtex/23eafd6303b9d...  black_hole
# 2902  https://www.bibsonomy.org/bibtex/220a9c864de99...  black_hole
# 2903  https://www.bibsonomy.org/bibtex/25669ce9d778f...  black_hole
#
#       publication_year                                              docno  \
# 0                 1985  https://www.bibsonomy.org/bibtex/22a964918445b...
# 1                 2009  https://www.bibsonomy.org/bibtex/2b58cdf90ec31...
# 2                 2003  https://www.bibsonomy.org/bibtex/20c909b757857...
# 3                 2004  https://www.bibsonomy.org/bibtex/250b4e765ba47...
# 4                 2007  https://www.bibsonomy.org/bibtex/21ea727184e9a...
# ...                ...                                                ...
# 2899              2011  https://www.bibsonomy.org/bibtex/2008452621683...
# 2900              1996  https://www.bibsonomy.org/bibtex/2bf142cb41666...
# 2901              2008  https://www.bibsonomy.org/bibtex/23eafd6303b9d...
# 2902              2005  https://www.bibsonomy.org/bibtex/220a9c864de99...
# 2903              2012  https://www.bibsonomy.org/bibtex/25669ce9d778f...
#
#                                                    text
# 0                   The oracles of Apollo in Asia Minor
# 1                                                Apollo
# 2                     The soviet space race with apollo
# 3     Biggest for-profit education company makes bid...
# 4     The Westminster Briefing: Presentation 5: Acce...
# ...                                                 ...
# 2899  Using Merkle Tree to Mitigate Cooperative Blac...
# 2900  Microscopic Origin of the Bekenstein-Hawking E...
# 2901     Instability of hyper-compact Kerr-like objects
# 2902  Supersymmetric black rings and three-charge su...
# 2903  Entropy of three-dimensional asymptotically fl...
#
# [2904 rows x 8 columns]

# %%
# Daten indexieren mit mehreren Feldern

# dataframe in Liste auf dicts umwandel

df_dict = df.to_dict(orient='records')

# %%
index_folder = "/home/anni/Schreibtisch/2023-2024-Data_Librarian_Ann-Kathrin_Christann/Modul_2/Modul_2-1/df_index"

fields=['docno', 'text', 'authors', 'searchterm', 'publication_year']

indexer_folder = pt.IterDictIndexer(index_folder, meta={'docno': 200, 'text': 4096}, overwrite=True)
index_ref = indexer_folder.index(df_dict, fields=fields)

print(f"path to our index: {index_ref.toString()}")
# Out:
# path to our index: /home/anni/Schreibtisch/2023-2024-Data_Librarian_Ann-Kathrin_Christann/Modul_2/Modul_2-1/df_index/data.properties

# %%
index = pt.IndexFactory.of(index_ref)

# %%
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 2904
# Number of terms: 12517
# Number of postings: 63382
# Number of fields: 5
# Number of tokens: 67160
# Field names: [docno, text, authors, searchterm, publication_year]
# Positions:   false

# %%
# Suchmaschine bauen

search_engine = pt.BatchRetrieve(index, wmodel="TF_IDF")

# %%
res = search_engine.search("star")
res
# Out:
#    qid  docid                                              docno  rank  \
# 0    1   1971  https://www.bibsonomy.org/bibtex/243c43624653e...     0
# 1    1   2278  https://www.bibsonomy.org/bibtex/2c0bfa300fa92...     1
# 2    1   1124  https://www.bibsonomy.org/bibtex/22e63892be64f...     2
# 3    1   2456  https://www.bibsonomy.org/bibtex/27ebf3b7c3a57...     3
# 4    1   1248  https://www.bibsonomy.org/bibtex/22a9084d0b8a5...     4
# 5    1   2114  https://www.bibsonomy.org/bibtex/232dd5ba508b3...     5
# 6    1   2314  https://www.bibsonomy.org/bibtex/28a2cc1c9d110...     6
# 7    1   2594  https://www.bibsonomy.org/bibtex/23ca77376532f...     7
# 8    1   2613  https://www.bibsonomy.org/bibtex/28c66c7872561...     8
# 9    1   1547  https://www.bibsonomy.org/bibtex/22a2c19fc7e3d...     9
# 10   1   1653  https://www.bibsonomy.org/bibtex/2d38cf58a2f73...    10
# 11   1   2369  https://www.bibsonomy.org/bibtex/2c99d5b17e080...    11
# 12   1   2444  https://www.bibsonomy.org/bibtex/2a7ff48315b99...    12
# 13   1   2455  https://www.bibsonomy.org/bibtex/2c245dde5b032...    13
# 14   1   2645  https://www.bibsonomy.org/bibtex/2b9ee464046a8...    14
# 15   1   2702  https://www.bibsonomy.org/bibtex/220fe67a8b1af...    15
# 16   1   2703  https://www.bibsonomy.org/bibtex/29b0c8527ac4f...    16
# 17   1   1185  https://www.bibsonomy.org/bibtex/2828c277261a8...    17
# 18   1   1956  https://www.bibsonomy.org/bibtex/2cc26b0f17b3c...    18
# 19   1   2199  https://www.bibsonomy.org/bibtex/29bef06e86aa6...    19
# 20   1   2138  https://www.bibsonomy.org/bibtex/298dc6c951b0f...    20
# 21   1   1415  https://www.bibsonomy.org/bibtex/22daff174d3a1...    21
# 22   1   1951  https://www.bibsonomy.org/bibtex/22fbbf81cccde...    22
# 23   1   2048  https://www.bibsonomy.org/bibtex/232f6c9f9e434...    23
# 24   1   2723  https://www.bibsonomy.org/bibtex/25f04475ca722...    24
# 25   1   2748  https://www.bibsonomy.org/bibtex/2a281231c761e...    25
# 26   1   2305  https://www.bibsonomy.org/bibtex/2d688702c36ca...    26
# 27   1   2756  https://www.bibsonomy.org/bibtex/23d1128aa3256...    27
# 28   1   2156  https://www.bibsonomy.org/bibtex/204f2269cbcbd...    28
# 29   1   2795  https://www.bibsonomy.org/bibtex/26e43ef3b6347...    29
# 30   1   2812  https://www.bibsonomy.org/bibtex/2464dd071f283...    30
# 31   1   2888  https://www.bibsonomy.org/bibtex/2e5f4a0d86192...    31
# 32   1   2830  https://www.bibsonomy.org/bibtex/28aefe337c3eb...    32
#
#        score query
# 0   3.884491  star
# 1   3.884491  star
# 2   3.810367  star
# 3   3.810367  star
# 4   3.739019  star
# 5   3.739019  star
# 6   3.739019  star
# 7   3.739019  star
# 8   3.739019  star
# 9   3.604049  star
# 10  3.604049  star
# 11  3.604049  star
# 12  3.604049  star
# 13  3.604049  star
# 14  3.604049  star
# 15  3.604049  star
# 16  3.604049  star
# 17  3.478484  star
# 18  3.478484  star
# 19  3.478484  star
# 20  3.305727  star
# 21  3.199783  star
# 22  3.149318  star
# 23  3.100419  star
# 24  3.100419  star
# 25  3.100419  star
# 26  3.053016  star
# 27  2.962429  star
# 28  2.796479  star
# 29  2.757856  star
# 30  2.093001  star
# 31  1.760794  star
# 32  1.496817  star

# %%
#  Dataframe speichern, um es für streamlit benutzen zu können


pickle.dump(df, open("/home/anni/Schreibtisch/2023-2024-Data_Librarian_Ann-Kathrin_Christann/Modul_2/Modul_2-1/df_publications.pkl", "wb"))

# %%
# streamlit

# %%
# %pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.30.0-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.2.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: click<9,>=7.0 in ./anaconda3/lib/python3.11/site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in ./anaconda3/lib/python3.11/site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in ./anaconda3/lib/python3.11/site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<24,>=16.8 in ./.local/lib/python3.11/site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in ./anaconda3/lib/python3.11/site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in ./anaconda3/lib/python3.11/site-packages (from streamlit) (9.4.0)
# Collecting protobuf<5,>=3.20 (from streamlit)
#   Downloading protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: pyarrow>=6.0 in ./anaconda3/lib/python3.11/site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in ./.local/lib/python3.11/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in ./anaconda3/lib/python3.11/site-packages (from streamlit) (2.31.0)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Downloading rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity<9,>=8.1.0 in ./anaconda3/lib/python3.11/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in ./anaconda3/lib/python3.11/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in ./anaconda3/lib/python3.11/site-packages (from streamlit) (4.7.1)
# Collecting tzlocal<6,>=1.1 (from streamlit)
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting validators<1,>=0.2 (from streamlit)
#   Downloading validators-0.22.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.41-py3-none-any.whl.metadata (14 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 21.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: tornado<7,>=6.0.3 in ./.local/lib/python3.11/site-packages (from streamlit) (6.4)
# Requirement already satisfied: watchdog>=2.1.5 in ./anaconda3/lib/python3.11/site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: jinja2 in ./anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in ./anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in ./anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: zipp>=0.5 in ./anaconda3/lib/python3.11/site-packages (from importlib-metadata<8,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in ./.local/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.local/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.17.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.11/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in ./anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in ./anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Downloading streamlit-1.30.0-py2.py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 24.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading altair-5.2.0-py3-none-any.whl (996 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 996.9/996.9 kB 18.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading GitPython-3.1.41-py3-none-any.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 12.5 MB/s eta 0:00:00
# Downloading protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 17.5 MB/s eta 0:00:00
# Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 20.9 MB/s eta 0:00:00
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.7 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: validators, tzlocal, smmap, protobuf, cachetools, blinker, rich, pydeck, gitdb, gitpython, altair, streamlit
# Successfully installed altair-5.2.0 blinker-1.7.0 cachetools-5.3.2 gitdb-4.0.11 gitpython-3.1.41 protobuf-4.25.2 pydeck-0.8.1b0 rich-13.7.0 smmap-5.0.1 streamlit-1.30.0 tzlocal-5.2 validators-0.22.0
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# streamlit Webseite bauen

# %%
import streamlit as st
import pyterrier as pt
import pickle

if not pt.started():
    pt.init()

def init():

    index = pt.IndexFactory.of("/home/anni/Desktop/2023-2024-Data_Librarian_Ann-Kathrin_Christann/Modul_2/Modul_2-1/df_index/data.properties")
    st.session_state["engine"] = pt.BatchRetrieve(index, wmodel="TF_IDF")
    st.session_state["data"] = pickle.load(open("/home/anni/Schreibtisch/2023-2024-Data_Librarian_Ann-Kathrin_Christann/Modul_2/Modul_2-1/df_publications.pkl", "rb"))

def search(query):

    res = st.session_state["engine"].search(query)
    fields_to_show = ['text', 'source', 'authors', 'searchterm', 'publication_year']

    for _, row in res.iterrows():
        score = round(row['score'], 2)
        entry = st.session_state["data"][st.session_state["data"]['docno'] == row['docno']].iloc[0]

        for field in fields_to_show:
            if field == "text":
                st.title(entry[field])
            else:
                st.write(f"{field.capitalize()}: \t {entry[field]}")

        st.write(f"Score: {score}")
        st.divider()


if not "engine" in st.session_state:
    init()

query = st.sidebar.text_input("Query")
st.sidebar.button("Search", on_click=search, args=(query,))
# Out:
# 2024-02-01 14:11:26.944
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/anni/.local/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# False
