# %%
## Export von Datensätzen aus Bibsonomy
# Export 1, Stichwort "space travel" - dataset_space

# %%
import pandas as pd

# %%
import requests
url = "https://www.bibsonomy.org/json/search/space%20travel?items=1000"
result = requests.get(url) 
dataset_space = result.json()

# %%
dataset_space
# Out:
# {'types': {'Bookmark': {'pluralLabel': 'Bookmarks'},
#   'Publication': {'pluralLabel': 'Publications'},
#   'GoldStandardPublication': {'pluralLabel': 'GoldStandardPublications'},
#   'GoldStandardBookmark': {'pluralLabel': 'GoldStandardBookmarks'},
#   'Tag': {'pluralLabel': 'Tags'},
#   'User': {'pluralLabel': 'Users'},
#   'Group': {'pluralLabel': 'Groups'},
#   'Sphere': {'pluralLabel': 'Spheres'}},
#  'properties': {'count': {'valueType': 'number'},
#   'date': {'valueType': 'date'},
#   'changeDate': {'valueType': 'date'},
#   'url': {'valueType': 'url'},
#   'id': {'valueType': 'url'},
#   'tags': {'valueType': 'item'},
#   'user': {'valueType': 'item'}},
#  'items': [{'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/4bdde78a14e668622d67e764f458ba1e/michelc',
#    'tags': ['medicine', 'space'],
#    'intraHash': '4bdde78a14e668622d67e764f458ba1e',
#    'label': 'What Space Travel Will Do To You',
#    'user': 'michelc',
#    'description': '',
# ...

# %%
# Export 2, Stichwort "moon"

# %%
url = "https://www.bibsonomy.org/json/search/moon?items=1000"
result = requests.get(url) 
dataset_moon = result.json()

# %%
# Export 3, Stichwort "lasers"

# %%
url = "https://www.bibsonomy.org/json/search/lasers?items=1000"
result = requests.get(url) 
dataset_lasers = result.json()

# %%
## Die drei Datensets zusammenführen

# %%
df_spacemoonlaser = pd.merge(pd.merge(dataset_space, dataset_moon, dataset_lasers))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_spacemoonlaser = pd.merge(pd.merge(dataset_space, dataset_moon, dataset_lasers))
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:148, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     131 @Substitution("\nleft : DataFrame or named Series")
#     132 @Appender(_merge_doc, indents=0)
#     133 def merge(
#    (...)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#     152         on=on,
#     153         left_on=left_on,
#     154         right_on=right_on,
#     155         left_index=left_index,
#     156         right_index=right_index,
# ...
